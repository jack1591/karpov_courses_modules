# %%
import pandas as pd

# %%
data = pd.read_csv('banking.csv')
data.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
data = data.drop(['duration'], axis = 1)

# %%
data.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu         1    999         0  nonexistent
# 1  cellular   nov         fri         1    999         0  nonexistent
# 2  cellular   jun         thu         3      6         2      success
# 3  cellular   apr         fri         2    999         0  nonexistent
# 4  cellular   aug         fri         1      3         1      success
#
#    emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
import numpy as np
numeric_columns = data.loc[:, data.dtypes != object].columns
data.loc[:, data.dtypes != object].head(2)
# Out:
#    age  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 0   44         1    999         0           1.4          93.444
# 1   53         1    999         0          -0.1          93.200
#
#    cons_conf_idx  euribor3m  nr_employed  y
# 0          -36.1      4.963       5228.1  0
# 1          -42.0      4.021       5195.8  0

# %%
categorical_columns = data.loc[:, data.dtypes == object].columns
data.loc[:, data.dtypes == object].head(2)
# Out:
#            job  marital education  default housing loan   contact month  \
# 0  blue-collar  married  basic.4y  unknown     yes   no  cellular   aug
# 1   technician  married   unknown       no      no   no  cellular   nov
#
#   day_of_week     poutcome
# 0         thu  nonexistent
# 1         fri  nonexistent

# %% [markdown]
# # EDA Анализ

# %%
data.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
data.describe()
# Out:
#                age      campaign         pdays      previous  emp_var_rate  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406      2.567593    962.475454      0.172963      0.081886
# std       10.42125      2.770014    186.910907      0.494901      1.570960
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons_price_idx  cons_conf_idx     euribor3m   nr_employed             y
# count    41188.000000   41188.000000  41188.000000  41188.000000  41188.000000
# mean        93.575664     -40.502600      3.621291   5167.035911      0.112654
# ...

# %%
data[numeric_columns].corr()
# Out:
#                      age  campaign     pdays  previous  emp_var_rate  \
# age             1.000000  0.004594 -0.034369  0.024365     -0.000371
# campaign        0.004594  1.000000  0.052584 -0.079141      0.150754
# pdays          -0.034369  0.052584  1.000000 -0.587514      0.271004
# previous        0.024365 -0.079141 -0.587514  1.000000     -0.420489
# emp_var_rate   -0.000371  0.150754  0.271004 -0.420489      1.000000
# cons_price_idx  0.000857  0.127836  0.078889 -0.203130      0.775334
# cons_conf_idx   0.129372 -0.013733 -0.091342 -0.050936      0.196041
# euribor3m       0.010767  0.135133  0.296899 -0.454494      0.972245
# nr_employed    -0.017725  0.144095  0.372605 -0.501333      0.906970
# y               0.030399 -0.066357 -0.324914  0.230181     -0.298334
#
#                 cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# age                   0.000857       0.129372   0.010767    -0.017725
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure()

fig.set_size_inches(10,8)

sns.heatmap(data[numeric_columns].corr(),
           xticklabels = numeric_columns,
           yticklabels = numeric_columns,
           cmap = 'BrBG',
           vmin = -1,
           vmax = 1)

plt.show()

# %%
# все возможные пары колонок в датасете
def get_redundant_pairs(dataset):
    pairs_to_drop = set()
    cols = dataset.columns
    for i in range (0,dataset.shape[1]):
        for j in range(0,i+1):
            pairs_to_drop.add((cols[i],cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(dataset, n = 5):
    au_corr = dataset.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(dataset)
    au_corr = au_corr.drop(labels = labels_to_drop).sort_values(ascending = False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(data[numeric_columns], 10))
# Out:
# Top Absolute Correlations
# emp_var_rate    euribor3m         0.972245
# euribor3m       nr_employed       0.945154
# emp_var_rate    nr_employed       0.906970
#                 cons_price_idx    0.775334
# cons_price_idx  euribor3m         0.688230
# pdays           previous          0.587514
# cons_price_idx  nr_employed       0.522034
# previous        nr_employed       0.501333
#                 euribor3m         0.454494
#                 emp_var_rate      0.420489
# dtype: float64

# %%
test = data[numeric_columns].drop(['emp_var_rate','euribor3m'], axis = 1)
get_top_abs_correlations(test,10)
# Out:
# pdays           previous          0.587514
# cons_price_idx  nr_employed       0.522034
# previous        nr_employed       0.501333
# pdays           nr_employed       0.372605
# nr_employed     y                 0.354678
# pdays           y                 0.324914
# previous        y                 0.230181
#                 cons_price_idx    0.203130
# campaign        nr_employed       0.144095
# cons_price_idx  y                 0.136211
# dtype: float64

# %%
data = data.drop(['emp_var_rate','euribor3m'], axis = 1)
numeric_columns = numeric_columns.drop(['emp_var_rate','euribor3m'])

# %%
from sklearn.feature_selection import VarianceThreshold

cutter = VarianceThreshold(threshold = 0.1)
cutter.fit(data[numeric_columns])

cutter.get_feature_names_out()
# Out:
# array(['age', 'campaign', 'pdays', 'previous', 'cons_price_idx',
#        'cons_conf_idx', 'nr_employed'], dtype=object)

# %%
numeric_columns
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'cons_price_idx',
#        'cons_conf_idx', 'nr_employed', 'y'],
#       dtype='object')

# %%
num_col = ['age', 'nr_employed']
for col in num_col:
    fig = plt.figure()
    fig.set_size_inches(10,8)
    sns.boxplot(y = col,x = data['y'].astype('category'), data = data)

plt.show()

# %% [markdown]
# ## Категориальные признаки

# %%
data.describe(include = 'object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome
# count   41188       41188        41188
# unique     10           5            3
# top       may         thu  nonexistent
# freq    13769        8623        35563

# %%
'''
Посмотрим на распределение клиентов по категориям
Если для всех значений таргета для каждой категории гистограммы не отличаются - значит признак не влияет на распределение
'''
for col in categorical_columns:
    g = sns.catplot(x = col, kind = 'count', col = 'y', data = data, sharey = False)
    g.set_xticklabels(rotation = 45)

# %%
data = data.drop(['loan', 'housing', 'marital'], axis = 1)
categorical_columns = categorical_columns.drop(['loan', 'housing', 'marital'])

# %%
data
# Out:
#        age          job            education  default    contact month  \
# 0       44  blue-collar             basic.4y  unknown   cellular   aug
# 1       53   technician              unknown       no   cellular   nov
# 2       28   management    university.degree       no   cellular   jun
# 3       39     services          high.school       no   cellular   apr
# 4       55      retired             basic.4y       no   cellular   aug
# ...    ...          ...                  ...      ...        ...   ...
# 41183   59      retired          high.school  unknown  telephone   jun
# 41184   31    housemaid             basic.4y  unknown  telephone   may
# 41185   42       admin.    university.degree  unknown  telephone   may
# 41186   48   technician  professional.course       no  telephone   oct
# 41187   25      student          high.school       no  telephone   may
#
#       day_of_week  campaign  pdays  previous     poutcome  cons_price_idx  \
# ...

# %% [markdown]
# # Преобразование категориальных признаков

# %%
data[categorical_columns].describe()
# Out:
#            job          education default   contact  month day_of_week  \
# count    41188              41188   41188     41188  41188       41188
# unique      12                  8       3         2     10           5
# top     admin.  university.degree      no  cellular    may         thu
# freq     10422              12168   32588     26144  13769        8623
#
#            poutcome
# count         41188
# unique            3
# top     nonexistent
# freq          35563

# %%
for col in categorical_columns:
    if data[col].nunique()<5:
        one_hot = pd.get_dummies(data[col], prefix = col, drop_first = True)*1
        data = pd.concat((data.drop(col, axis = 1), one_hot),axis = 1)
    else:
        mean_target = data.groupby(col)['y'].mean()
        data[col] = data[col].map(mean_target)

# %%
mean_target
# Out:
# day_of_week
# fri    0.108087
# mon    0.099483
# thu    0.121188
# tue    0.117800
# wed    0.116671
# Name: y, dtype: float64

# %%
data.head()
# Out:
#    age       job  education     month  day_of_week  campaign  pdays  previous  \
# 0   44  0.068943   0.102490  0.106021     0.121188         1    999         0
# 1   53  0.108260   0.145003  0.101439     0.108087         1    999         0
# 2   28  0.112175   0.137245  0.105115     0.121188         3      6         2
# 3   39  0.081381   0.108355  0.204787     0.108087         2    999         0
# 4   55  0.252326   0.102490  0.106021     0.108087         1      3         1
#
#    cons_price_idx  cons_conf_idx  nr_employed  y  default_unknown  \
# 0          93.444          -36.1       5228.1  0                1
# 1          93.200          -42.0       5195.8  0                0
# 2          94.055          -39.8       4991.6  1                0
# 3          93.075          -47.1       5099.1  0                0
# 4          92.201          -31.4       5076.2  1                0
#
#    default_yes  contact_telephone  poutcome_nonexistent  poutcome_success
# ...

# %% [markdown]
# # Построение модели

# %%
X = data.drop('y', axis = 1)
Y = data['y']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,
                                                   random_state = 0,
                                                   test_size = 0.2)

# %%
X_train.shape[0], X_test.shape[0]
# Out:
# (32950, 8238)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
pipe = Pipeline([('scaler', StandardScaler()),
                ('LR', LogisticRegression(penalty = None))]) # убрали регуляризацию
pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('LR', LogisticRegression(penalty=None))])

# %%
pipe.score(X_test, Y_test)
# Out:
# 0.9013109978150037

# %%
# Различные методы для моделей классификации

print(pipe.classes_)

print(pipe.predict(X_test.head(1)))

print(pipe.predict_proba(X_test.head(1)))

print(pipe.decision_function(X_test.head(2)))
# Out:
# [0 1]
# [0]
# [[0.8814013 0.1185987]]
# [-2.00576745 -2.25764275]

# %%
X_test.head(1)
# Out:
#        age       job  education     month  day_of_week  campaign  pdays  \
# 15500   51  0.068943   0.078246  0.204787     0.099483         4    999
#
#        previous  cons_price_idx  cons_conf_idx  nr_employed  default_unknown  \
# 15500         0          93.075          -47.1       5099.1                0
#
#        default_yes  contact_telephone  poutcome_nonexistent  poutcome_success
# 15500            0                  0                     1                 0

# %%
from sklearn.metrics import confusion_matrix

tn, tp, fn, fp = confusion_matrix(Y_test, pipe.predict(X_test)).ravel()

conf_matrix = [[tp, fn],
              [fp, tn]]
print(conf_matrix)
# Out:
# [[np.int64(117), np.int64(696)], [np.int64(217), np.int64(7208)]]

# %%
pipe.classes_
# Out:
# array([0, 1])

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(Y_test, pipe.predict(X_test), labels = pipe.classes_)

cmp = ConfusionMatrixDisplay(confusion_matrix = cm)
fig, ax = plt.subplots(figsize = (16,10))
cmp.plot(ax = ax)
plt.show()

# %%
from sklearn.metrics import recall_score, precision_score, accuracy_score, f1_score

print(f'Accuracy is {accuracy_score(Y_test,pipe.predict(X_test)):.3f}')
print(f'Recall is {recall_score(Y_test,pipe.predict(X_test)):.3f}')
print(f'Precision is {precision_score(Y_test,pipe.predict(X_test)):.3f}')
print(f'F1 score is {f1_score(Y_test,pipe.predict(X_test)):.3f}')
# Out:
# Accuracy is 0.901
# Recall is 0.238
# Precision is 0.650
# F1 score is 0.348

# %%
pipe.predict_proba(X_test)[:,1]
# Out:
# array([0.1185987 , 0.09469225, 0.0284654 , ..., 0.05291616, 0.03815648,
#        0.00651352])

# %%
from sklearn.metrics import precision_recall_curve

precision_recall_curve(Y_test,pipe.predict_proba(X_test)[:,1])
# Out:
# (array([0.11082787, 0.11084133, 0.11085478, ..., 1.        , 1.        ,
#         1.        ]),
#  array([1.        , 1.        , 1.        , ..., 0.00219058, 0.00109529,
#         0.        ]),
#  array([0.00292011, 0.00323579, 0.00434602, ..., 0.9046428 , 0.90522311,
#         0.90809827]))

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(Y_test,pipe.predict_proba(X_test)[:,1])

f_scores = 2 * precision*recall / (precision+recall)

print(f"Best F-score {np.max(f_scores)}")
print(f"Threshold for Best F-score {thresholds[np.argmax(f_scores)]}")
# Out:
# Best F-score 0.4751703992210321
# Threshold for Best F-score 0.1844666851474962

# %%
print(precision[np.argmax(f_scores)])
print(recall[np.argmax(f_scores)])
# Out:
# 0.42769500438212094
# 0.5345016429353778

# %%
threshold = thresholds[np.argmax(f_scores)]
y_pred = (pipe.predict_proba(X_test)[:,1] > threshold).astype('float')

# %%
cm = confusion_matrix(Y_test, y_pred, labels = pipe.classes_)

cmp = ConfusionMatrixDisplay(confusion_matrix = cm)
fig, ax = plt.subplots(figsize = (16, 10))
cmp.plot(ax = ax)

plt.show()

# %% [markdown]
# # Построение ROC/PR-кривой

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(Y_test, pipe.predict_proba(X_test)[:, 1])

from sklearn.metrics import RocCurveDisplay

RocCurveDisplay(fpr = fpr, tpr = tpr).plot()
# Out:
# C:\Users\jackt\anaconda3\Lib\site-packages\sklearn\metrics\_plot\roc_curve.py:189: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax_.legend(loc="lower right")

# %%
RocCurveDisplay.from_estimator(pipe, X_test, Y_test)

# %%
from sklearn.metrics import auc

auc(fpr, tpr) # вертикаль, горизонталь
# Out:
# np.float64(0.7856283713818973)

# %%
from sklearn.metrics import PrecisionRecallDisplay
precision, recall, thresholds = precision_recall_curve(Y_test,pipe.predict_proba(X_test)[:,1])

#PrecisionRecallDisplay(precision = precision, recall = recall).plot()
PrecisionRecallDisplay.from_estimator(pipe, X_test, Y_test)

# %%
PrecisionRecallDisplay(precision = precision, recall = recall).plot()

# %%
auc(recall, precision)
# Out:
# np.float64(0.4603788059079619)

# %% [markdown]
# # Рисование калибровочной кривой

# %%
from sklearn.calibration import CalibrationDisplay

CalibrationDisplay.from_estimator(pipe, X_test, Y_test, n_bins = 20)

# %%
from sklearn.svm import LinearSVC

pipe_svm = Pipeline([('scaler_svm', StandardScaler()),
                    ('SVM', LinearSVC())])
pipe_svm.fit(X_train, Y_train)
pipe_svm.score(X_test, Y_test)
# Out:
# 0.9025248846807478

# %%
print(f'Accuracy is {accuracy_score(Y_test, pipe_svm.predict(X_test)):.3f}')
print(f'Precision is {precision_score(Y_test, pipe_svm.predict(X_test)):.3f}')
print(f'Recall is {recall_score(Y_test, pipe_svm.predict(X_test)):.3f}')
print(f'F-score is {f1_score(Y_test, pipe_svm.predict(X_test)):.3f}')
# Out:
# Accuracy is 0.903
# Precision is 0.688
# Recall is 0.220
# F-score is 0.334

# %%
PrecisionRecallDisplay.from_estimator(pipe_svm, X_test, Y_test)

# %%
RocCurveDisplay.from_estimator(pipe_svm, X_test, Y_test)

# %%
CalibrationDisplay.from_estimator(pipe_svm, X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 CalibrationDisplay.from_estimator(pipe_svm, X_test, Y_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\calibration.py:1291, in CalibrationDisplay.from_estimator(cls, estimator, X, y, n_bins, strategy, pos_label, name, ref_line, ax, **kwargs)
#    1188 @classmethod
#    1189 def from_estimator(
#    1190     cls,
#    (...)
#    1201     **kwargs,
#    1202 ):
#    1203     """Plot calibration curve using a binary classifier and data.
#    1204
#    1205     A calibration curve, also known as a reliability diagram, uses inputs
#    (...)
#    1289     >>> plt.show()
#    1290     """
# -> 1291     y_prob, pos_label, name = cls._validate_and_get_response_values(
#    1292         estimator,
#    1293         X,
#    1294         y,
#    1295         response_method="predict_proba",
# ...

# %%
# Преобразуем выходы модели в вероятности
pipe_svm.decision_function(X_test.head(2))

def sigmoid(output):
    return 1/(1+np.exp(-output))

pred_prob = sigmoid(pipe_svm.decision_function(X_test))

# %%
CalibrationDisplay.from_predictions(Y_test, pred_prob, n_bins = 20)

# %%
# Калибровка Плата
from sklearn.calibration import CalibratedClassifierCV
calibration = CalibratedClassifierCV(pipe_svm, cv = 5, method = 'sigmoid')
calibration.fit(X_train, Y_train)

calibrated_probs = calibration.predict_proba(X_test)[:, 1]

# %%
calibrated_probs

# %%
CalibrationDisplay.from_predictions(Y_test, calibrated_probs, n_bins = 20)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.set_size_inches(10,8)

plt.hist(pipe.predict_proba(X_test)[:, 1])

plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.set_size_inches(10,8)

plt.hist(calibrated_probs)

plt.show()

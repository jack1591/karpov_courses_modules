# %%
import numpy as np
X = np.array([
    [1, 1],
    [3, 1]
])
Y = np.array([10, 4])
beta = np.array([1, 1])
learning_rate = 0.1
print(np.dot(X, beta) - Y)
beta_next = beta - learning_rate * (np.dot(X, beta) - Y)
beta_next
# Out:
# [-8  0]
# array([1.8, 1. ])

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ### Данные

# %%
aneks = []

with open('anek.txt', 'r', encoding = 'utf-8') as f:
    aneks.extend(f.read().split('\n'))

# %%
len(aneks)
# Out:
# 125103

# %%
class Vocabulary:
    def __init__(self):
        self.vocabulary = ['_', '*', '<'] # start, end, padding
        self.vocabulary.extend('абвгдеёжзийклмнопрстуфхцчшщъыьэюя')
        self.vocabulary.extend('абвгдеёжзийклмнопрстуфхцчшщъыьэюя'.upper())
        self.vocabulary.extend('0123456789 ,.!?-')

        self._idx2char = {i: char for i, char in enumerate(self.vocabulary)}
        self._char2idx = {char: i for i, char in enumerate(self.vocabulary)}

    def get_vocabulary(self):
        return self.vocabulary

    def idx2char(self, idx: int):
        if idx not in self._idx2char:
            return '<'
        return self._idx2char[idx]

    def char2idx(self, char: str):
        if char not in self._char2idx:
            return self.get_pad()
        return self._char2idx[char]

    def encode(self, text):
        result = [self.char2idx(char) for char in text]
        result = [self.get_sos()] + result + [self.get_eos()]
        return result

    def get_sos(self):
        return self.char2idx('_')

    def get_eos(self):
        return self.char2idx('#')

    def get_pad(self):
        return self.char2idx('<')

# %%
from torch.utils.data import Dataset

class Anekdotes(Dataset):
    def __init__(self, aneks):
        self.aneks = aneks
        self.vocab = Vocabulary()

    def __getitem__(self, idx):
        return torch.LongTensor(self.vocab.encode(self.aneks[idx]))

    def __len__(self):
        return len(self.aneks)

# %%
dataset = Anekdotes(aneks)

# %%
dataset[10]
# Out:
# tensor([ 0, 61, 22, 12, 20, 15, 12, 26, 79, 22, 18, 19, 12, 15, 79,  4, 23, 20,
#         10, 23, 13, 14, 23, 81, 79, 55, 18, 15, 32, 14, 18, 79, 27,  8, 20,  8,
#         11, 79,  7,  5,  3, 79, 27,  3, 21,  3, 79,  8, 16, 23, 79, 23,  7,  3,
#         15, 18, 21, 32, 79,  8,  8, 79, 23, 22, 18, 19, 12, 22, 32, 81,  2])

# %%
aneks[10]
# Out:
# 'Штирлиц топил буржуйку. Только через два часа ему удалось ее утопить.'

# %%
from torch.utils.data import random_split

train_dataset, valid_dataset = random_split(dataset, (int(len(dataset) * 0.9), len(dataset) - int(len(dataset) * 0.9)))

# %%
from torch.nn.utils.rnn import pad_sequence
pad_idx = dataset.vocab.get_pad()

def collate_fn(batch):
    return pad_sequence([b[:256] for b in batch], padding_value = pad_idx, batch_first = True)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size = 256, collate_fn = collate_fn, pin_memory = True)
valid_loader = DataLoader(valid_dataset, batch_size = 256, collate_fn = collate_fn, pin_memory = True)

# %% [markdown]
# ### RNN

# %% [markdown]
# ### [RNN](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html)
#
# $$h_t = \tanh\left( x_tW_{xh}^T + b_{xh} + h_{t-1}W_{hh}^T + b_{hh} \right)$$
#
# либо если `bias=False`, то
#
# $$h_t = \tanh\left( x_tW_{xh}^T + h_{t-1}W_{hh}^T \right)$$
#
# Параметры:
#
#  - `input_size` - размерность $x_i$
#  - `hidden_size` - размерность $h_i$
#  - `num_layers` - количество слоев (по умолчанию 1)
#  - `dropout` - какой делать дропаут при количестве слоев > 1 (по умолчанию 0)
#  - `bidirectional` - двунаправленная

# %%
layer = nn.RNN(input_size = 3, hidden_size = 6)

# %%
layer
# Out:
# RNN(3, 6)

# %%
print(layer.weight_hh_l0) # веса h нулевого слоя
print()
print(layer.weight_hh_l0.shape)
# Out:
# Parameter containing:
# tensor([[ 0.0106, -0.1501, -0.0914, -0.1506,  0.1970, -0.0896],
#         [ 0.2588,  0.2261, -0.0560, -0.2155,  0.0189,  0.3039],
#         [-0.2050,  0.1308, -0.1901,  0.3219,  0.2163,  0.1753],
#         [ 0.2110,  0.3378, -0.1992, -0.4025,  0.2505, -0.3658],
#         [-0.3788, -0.2742,  0.0777,  0.0097,  0.3975,  0.1675],
#         [-0.2038, -0.2718,  0.2254,  0.3939,  0.1319, -0.1879]],
#        requires_grad=True)
#
# torch.Size([6, 6])

# %%
print(layer.weight_ih_l0)
print()
print(layer.weight_ih_l0.shape)
# Out:
# Parameter containing:
# tensor([[ 0.3290,  0.2191, -0.4067],
#         [-0.3450, -0.2553, -0.0409],
#         [-0.3740,  0.0513, -0.2342],
#         [-0.2509, -0.1051, -0.0361],
#         [-0.0231,  0.0900,  0.2582],
#         [-0.2899,  0.1978, -0.3156]], requires_grad=True)
#
# torch.Size([6, 3])

# %%
print(layer.bias_hh_l0)
print()
print(layer.bias_hh_l0.shape)
# Out:
# Parameter containing:
# tensor([ 0.0585,  0.1947,  0.0014, -0.3466, -0.3621, -0.0221],
#        requires_grad=True)
#
# torch.Size([6])

# %%
print(layer.bias_ih_l0)
print()
print(layer.bias_ih_l0.shape)
# Out:
# Parameter containing:
# tensor([ 0.1790, -0.2744,  0.3275, -0.1340, -0.0170, -0.0596],
#        requires_grad=True)
#
# torch.Size([6])

# %%
batch_size = 5
seq_len = 7
input_dim = 3

layer = nn.RNN(input_size = 3, hidden_size = 6, batch_first = True)

x = torch.randn(batch_size, seq_len, input_dim)

hs, h_last = layer(x)

print(hs)
print()
print(hs.shape)


print(h_last)
print()
print(h_last.shape)
# Out:
# tensor([[[ 0.1138, -0.2224,  0.8280,  0.6649,  0.6795,  0.4153],
#          [ 0.7076, -0.6852, -0.3729, -0.5432,  0.4151,  0.8521],
#          [-0.1719, -0.7046,  0.0519, -0.1054,  0.4857,  0.9219],
#          [ 0.1128, -0.5237,  0.6170,  0.6327,  0.6789,  0.6284],
#          [ 0.4224, -0.5793,  0.3446, -0.1914,  0.5006,  0.8291],
#          [-0.2430, -0.5042,  0.8143,  0.5288,  0.7344,  0.8424],
#          [ 0.7493, -0.6730, -0.3429, -0.0020,  0.6129,  0.6803]],
#
#         [[ 0.5087, -0.4485, -0.0321,  0.2184,  0.6467,  0.8015],
#          [ 0.4701, -0.4457, -0.1078,  0.2790,  0.8283,  0.9346],
#          [ 0.4569, -0.5987, -0.0020, -0.0377,  0.5138,  0.6282],
#          [ 0.2673, -0.6328,  0.1823,  0.0717,  0.5424,  0.6897],
#          [ 0.4979, -0.6752, -0.4887, -0.1803,  0.6686,  0.9528],
#          [ 0.1577, -0.5899,  0.0722,  0.2389,  0.6479,  0.8506],
#          [ 0.0685, -0.6700,  0.3222, -0.3752,  0.1758,  0.8607]],
#
#         [[ 0.3984, -0.2688,  0.4452,  0.5938,  0.7842,  0.7665],
#          [ 0.4232, -0.4878,  0.4950,  0.0349,  0.5745,  0.6155],
#          [ 0.1348, -0.6494,  0.2697, -0.1429,  0.6129,  0.9463],
#          [ 0.2393, -0.7434,  0.1495, -0.0055,  0.3546,  0.5733],
#          [ 0.0590, -0.5474,  0.7033,  0.4263,  0.5600,  0.3691],
#          [ 0.6443, -0.6714, -0.2955, -0.2444,  0.6104,  0.8902],
#          [ 0.0154, -0.4053,  0.5719,  0.6935,  0.8591,  0.8522]],
#
#         [[ 0.3187, -0.5841,  0.2566, -0.1801,  0.1275,  0.4427],
#          [ 0.2167, -0.8132, -0.2646, -0.6481, -0.1460,  0.6375],
#          [-0.3972, -0.5389,  0.6550,  0.5251,  0.6250,  0.8460],
#          [ 0.4335, -0.6787, -0.1781, -0.4480,  0.3994,  0.9704],
#          [-0.4862, -0.7404,  0.6138, -0.2920, -0.0215,  0.8087],
#          [-0.0997, -0.7507,  0.3150, -0.1137,  0.1864,  0.8712],
#          [-0.0015, -0.5275,  0.5201,  0.4732,  0.7093,  0.8891]],
#
#         [[ 0.2770,  0.0076,  0.8317,  0.8814,  0.8938,  0.5477],
#          [ 0.5836, -0.7342, -0.2567, -0.8521, -0.0795,  0.9001],
#          [-0.4130, -0.6249,  0.5043,  0.4241,  0.5974,  0.7947],
#          [-0.0094, -0.4805,  0.7735,  0.2656,  0.5657,  0.9222],
#          [ 0.3502, -0.8077, -0.2278, -0.6927, -0.0642,  0.8372],
#          [-0.1592, -0.6567,  0.1742,  0.3241,  0.5747,  0.8019],
#          [ 0.2391, -0.7837, -0.2445, -0.7416, -0.2082,  0.9161]]],
#        grad_fn=<TransposeBackward1>)
#
# torch.Size([5, 7, 6])
# tensor([[[ 0.7493, -0.6730, -0.3429, -0.0020,  0.6129,  0.6803],
#          [ 0.0685, -0.6700,  0.3222, -0.3752,  0.1758,  0.8607],
#          [ 0.0154, -0.4053,  0.5719,  0.6935,  0.8591,  0.8522],
#          [-0.0015, -0.5275,  0.5201,  0.4732,  0.7093,  0.8891],
#          [ 0.2391, -0.7837, -0.2445, -0.7416, -0.2082,  0.9161]]],
#        grad_fn=<StackBackward0>)
#
# torch.Size([1, 5, 6])

# %% [markdown]
# ### GRU

# %% [markdown]
# ### [GRU](https://pytorch.org/docs/stable/generated/torch.nn.GRU.html)
#
# $$r_t = \sigma\left( x_t W_{xr}^T + b_{xr} + h_{t-1}W_{hr}^T + b_{hr} \right)$$
# $$z_t = \sigma\left( x_t W_{xz}^T + b_{xz} + h_{t-1}W_{hz}^T + b_{hz} \right)$$
# $$\hat{h_t} = \tanh\left( x_tW_{xh}^T + b_{xh} + r_t * (h_{t-1}W_{hh}^T + b_{hh}) \right)$$
# $$h_t = (1 - z_t) * \hat{h_t} + z_t * h_{t-1}$$
#
# Параметры такие же как у RNN.

# %%
layer = nn.GRU(input_size = 3, hidden_size = 6)
layer
# Out:
# GRU(3, 6)

# %%
print(layer.weight_hh_l0)
print()
print(layer.weight_hh_l0.shape)
# Out:
# Parameter containing:
# tensor([[ 0.3742, -0.2334,  0.1113, -0.0752, -0.0941, -0.2707],
#         [ 0.4009, -0.3875, -0.1850, -0.3604, -0.2896,  0.1956],
#         [ 0.0871, -0.2621, -0.3444, -0.0309, -0.0194, -0.2811],
#         [ 0.3339,  0.1116,  0.3438, -0.3391,  0.1923,  0.1353],
#         [ 0.2548, -0.1119,  0.3183, -0.0745, -0.3444,  0.3575],
#         [-0.3444, -0.1301,  0.2107, -0.2630,  0.1704,  0.3809],
#         [ 0.0238, -0.0815, -0.1556,  0.0531, -0.2025,  0.3184],
#         [-0.1683, -0.3146,  0.3330,  0.2763,  0.3941, -0.0695],
#         [ 0.0663,  0.2003, -0.2391,  0.2505,  0.2385, -0.0165],
#         [ 0.0898, -0.2620, -0.2987, -0.1413, -0.1569, -0.1332],
#         [-0.3473, -0.1799,  0.0173,  0.3402,  0.0499, -0.1236],
#         [-0.0621, -0.3882, -0.1765,  0.1198,  0.2936, -0.1347],
#         [-0.0302,  0.0476, -0.3541, -0.2422, -0.0507, -0.2164],
#         [-0.2951,  0.0105,  0.0555,  0.2433,  0.0223,  0.1274],
#         [ 0.1253, -0.3715, -0.3477,  0.2382,  0.1942,  0.1768],
#         [ 0.0048, -0.0451, -0.0494, -0.2686, -0.1706, -0.1974],
#         [-0.1852,  0.1934,  0.2991, -0.1098,  0.1103,  0.2816],
#         [-0.1136, -0.3912, -0.1585,  0.0541, -0.0238,  0.1277]],
#        requires_grad=True)
#
# torch.Size([18, 6])

# %%
print(layer.weight_ih_l0)
print()
print(layer.weight_ih_l0.shape)
# Out:
# Parameter containing:
# tensor([[-0.3249, -0.2444,  0.3381],
#         [ 0.0487,  0.2291,  0.0505],
#         [ 0.0396, -0.1667,  0.0272],
#         [ 0.2290, -0.2678, -0.0907],
#         [-0.2262,  0.0021, -0.0819],
#         [-0.2806,  0.2957,  0.3396],
#         [ 0.1527, -0.1967,  0.2015],
#         [ 0.4038,  0.1536,  0.1568],
#         [ 0.2664,  0.1754,  0.0498],
#         [ 0.2368,  0.2024,  0.0138],
#         [ 0.1206, -0.2597,  0.3590],
#         [-0.1917, -0.1425,  0.0541],
#         [-0.3599,  0.4059,  0.2336],
#         [ 0.3364,  0.2106,  0.3841],
#         [-0.1822,  0.0414,  0.3902],
#         [-0.0230, -0.1260, -0.0107],
#         [ 0.1697,  0.1795, -0.2993],
#         [ 0.2518, -0.2171, -0.0813]], requires_grad=True)
#
# torch.Size([18, 3])

# %%
print(layer.bias_hh_l0)
print()
print(layer.bias_hh_l0.shape)
# Out:
# Parameter containing:
# tensor([-0.0423, -0.3983,  0.0295, -0.0835,  0.2107,  0.1811,  0.2159,  0.0721,
#          0.3572,  0.2963, -0.3730, -0.2727, -0.1665, -0.2514,  0.0808, -0.0525,
#         -0.0103, -0.3498], requires_grad=True)
#
# torch.Size([18])

# %%
print(layer.bias_ih_l0)
print()
print(layer.bias_ih_l0.shape)
# Out:
# Parameter containing:
# tensor([ 0.1305,  0.3838, -0.3481, -0.3062,  0.3642, -0.0331, -0.0885,  0.2550,
#         -0.3404,  0.3689,  0.2034,  0.3244,  0.2483,  0.3615, -0.3820,  0.1655,
#          0.3723,  0.3048], requires_grad=True)
#
# torch.Size([18])

# %% [markdown]
# ### LSTM

# %% [markdown]
# ### [LSTM](https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html)
#
# Более страшные формулы, все в целом очень похоже на GRU. Параметры те же.

# %%
layer = nn.LSTM(input_size = 3, hidden_size = 6)
layer
# Out:
# LSTM(3, 6)

# %% [markdown]
# ### AnekdotesRNN

# %%
class AnekdotesRNN(nn.Module):
    def __init__(self, num_tokens: int, emb_size: int = 32, hidden_size : int = 256):
        super().__init__()
        # каждый токен кодируем вектором размерности emb_size
        # padding_idx - индекс нулевого слова, обновляться не будет
        self.embedding = nn.Embedding(num_tokens, emb_size, padding_idx = pad_idx)

        self.rnn = nn.LSTM(
            input_size = emb_size,
            hidden_size = hidden_size,
            num_layers = 4,
            dropout = 0.3,
            batch_first = True
        )

        self.output = nn.Sequential(
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(),
            nn.Linear(hidden_size, num_tokens)
        )

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.rnn(x)
        x = self.output(x)

        return x

# %%
model = AnekdotesRNN(num_tokens = len(dataset.vocab.get_vocabulary()))

# %% [markdown]
# ### Функции для обучения
# в качестве таргета мы берем последовательность, начиная с 1 элемента, потому что предсказываем следующий токен
# вход на обучение: [1, 2, 3, 4]
# таргет: [2, 3, 4, 5]

# %%
from tqdm import tqdm

def train(model):
    model.train()

    train_loss = 0
    
    for x in tqdm(train_loader, desc = 'Train'):
        x = x.to(device)
        
        optimizer.zero_grad()

        output = model(x[:, :-1]).transpose(1, 2)
        
        loss = loss_fn(output, x[:, 1:])

        train_loss += loss.item()

        loss.backward()
        optimizer.step()

    train_loss /= len(train_loader)

    return train_loss

# %% [markdown]
# Поскольку мы используем `nn.CrossEntropyLoss`, то посмотрим в каком размере она ожидает входы:
#
#  - Input: Shape $(C)$, $(N, C)$ or $(N, C, d_1, d_2, ..., d_K)$ with $K \geq 1$ in the case of $K$-dimensional loss.
#  - Target: $(N)$ or $(N, d_1, d_2, ..., d_K)$ with $K \geq 1$ in the case of $K$-dimensional loss where each value should be between $[0, C)$.

# %%
x = next(iter(train_loader))
output = model(x[:, :-1])
print(output.shape)
print(x[:, 1:].shape)

print()

print(output.transpose(1, 2).shape)
# Out:
# C:\Users\jackt\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# torch.Size([256, 255, 85])
# torch.Size([256, 255])
#
# torch.Size([256, 85, 255])

# %%
print(len(dataset.vocab.get_vocabulary()))
# Out:
# 85

# %%
@torch.inference_mode()
def evaluate(model, loader):
    model.eval()
    total_loss = 0
    for x in tqdm(loader, desc = 'Evaluation'):
        x = x.to(device)

        output = model(x[:, :-1]).transpose(1, 2)

        loss = loss_fn(output, x[:, 1:])

        total_loss += loss.item()

    total_loss /= len(loader)
    return total_loss

# %%
def plot_stats(
    train_loss: list[float],
    valid_loss: list[float],
    title
):
    plt.figure(figsize = (16, 10))
    plt.title(title)
    plt.plot(train_loss, label = 'Train loss')
    plt.plot(valid_loss, label = 'Valid loss')
    plt.legend()
    plt.grid()
    plt.show()

# %%
def whole_train_value_cycle(
    model,
    title: str,
    num_epochs = 3,
):
    train_loss_history = []
    valid_loss_history = []

    for epoch in range(num_epochs):
        train_loss = train(model)
        valid_loss = evaluate(model)

        train_loss_history.append(train_loss)
        valid_loss_history.append(valid_loss)

        clear_output(wait = True)

        plot_stats(train_loss_history, valid_loss_history, title)

# %% [markdown]
# ### Обучение

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
print(torch.cuda.get_device_name() if torch.cuda.is_available() else None)
# Out:
# cpu
# None

# %%
from torch.optim import Adam
model = model.to(device)

optimizer = Adam(model.parameters(), lr = 1e-3)
loss_fn = nn.CrossEntropyLoss(ignore_index = pad_idx)

whole_train_value_cycle(model, 'Anekdotes RNN', 3)
# Out:
# C:\Users\jackt\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Train:   1%|          | 5/440 [00:47<1:09:06,  9.53s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 7
#       4 optimizer = Adam(model.parameters(), lr = 1e-3)
#       5 loss_fn = nn.CrossEntropyLoss(ignore_index = pad_idx)
# ----> 7 whole_train_value_cycle(model, 'Anekdotes RNN', 3)
#
# Cell In[38], line 10, in whole_train_value_cycle(model, title, num_epochs)
#       7 valid_loss_history = []
#       9 for epoch in range(num_epochs):
# ---> 10     train_loss = train(model)
#      11     valid_loss = evaluate(model)
#      13     train_loss_history.append(train_loss)
#
# Cell In[29], line 19, in train(model)
#      15     loss = loss_fn(output, x[:, 1:])
#      17     train_loss += loss.item()
# ---> 19     loss.backward()
#      20     optimizer.step()
#      22 train_loss /= len(train_loader)
#
# File ~\anaconda3\Lib\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)
#     628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~\anaconda3\Lib\site-packages\torch\autograd\__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File ~\anaconda3\Lib\site-packages\torch\autograd\graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:
